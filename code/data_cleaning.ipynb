# %% [markdown]
# ---
# title: "Data Cleaning"
# ---

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)

# %% [markdown]
# ### Load Dataframe

# %%
movies_df = pd.read_csv("../data/raw/movies.csv")

print(len(movies_df))
# Out:
# 7333

# %% [markdown]
# ### Movies With Identical Titles

# %%
# Find all duplicated titles
duplicate_titles = movies_df[movies_df.duplicated(subset = "Title", keep = False)]

# Find true duplicates (same title and same year)
true_duplicates = movies_df[movies_df.duplicated(subset = ["Title", "Year"], keep = False)]

# Get non-true duplicates (same title, different year)
mask = duplicate_titles.index.difference(true_duplicates.index)

# Append year to title for non-true duplicates
movies_df.loc[mask, "Title"] = (
    movies_df.loc[mask, "Title"] + " (" + movies_df.loc[mask, "Year"].astype(str) + ")"
)

# Drop true duplicate movies
movies_df = movies_df.drop_duplicates(subset = ["Title", "Year"], keep = "first")

# %% [markdown]
# ### Convert Data Types

# %%
# Convert columns to specified data types
movies_df["Year"] = pd.to_numeric(movies_df["Year"], errors = "coerce").astype("Int64")

movies_df["Runtime"] = movies_df["Runtime"].str.extract(r"(\d+)").astype("Int64")

movies_df["Metascore_Rating"] = pd.to_numeric(movies_df["Metascore_Rating"], errors = "coerce").astype("Int64") / 10
movies_df["Rotten_Tomatoes_Rating"] = movies_df["Rotten_Tomatoes_Rating"].str.rstrip('%').astype("Int64") / 10
movies_df["IMDB_Rating"] = pd.to_numeric(movies_df["IMDB_Rating"], errors = "coerce")
movies_df["TMDB_Rating"] = movies_df["TMDB_Rating"].round(1)

movies_df["Keywords"] = movies_df["Keywords"].str.split(", ")

movies_df["Release_Date"] = pd.to_datetime(movies_df["Release_Date"], errors = "coerce")
movies_df["Release_Month"] = movies_df["Release_Date"].dt.month_name()

movies_df["Awards"] = movies_df["Awards"].astype(str).str.lower()

# %% [markdown]
# ### Create Additional Columns

# %%
# Alter Awards column to only include oscar counts and create new columns based on nominations vs wins
movies_df["Awards"] = movies_df["Awards"].apply(lambda x: x.split("oscar")[0] + "oscar" if "oscar" in str(x) else np.nan)
movies_df["Oscar_Wins"] = movies_df["Awards"].apply(lambda x: int(x.split("won")[1].split("oscar")[0].strip()) if "won" in str(x) else 0)
movies_df["Oscar_Nominations"] = movies_df["Awards"].apply(lambda x: int(x.split("nominated for")[1].split("oscar")[0].strip()) if "nominated" in str(x) else 0)
movies_df = movies_df.drop(columns = ["Awards"])

# Add boolean column for oscar win or not
movies_df["Won_Award"] = movies_df["Oscar_Wins"] != 0

# Return_On_Investment column calculated by dividing movie revenue by budget
movies_df["Return_On_Investment"] = movies_df["Revenue"] / movies_df["Budget"]

# Average_Rating column calculated by obatining the mean of all provided rating scores
movies_df["Average_Rating"] = movies_df[["Metascore_Rating", "IMDB_Rating", "Rotten_Tomatoes_Rating", "TMDB_Rating"]].mean(axis = 1)

# Z-Score normalization for Budget and Revenue columns
movies_df["Budget_Normalized"] = (movies_df["Budget"] - movies_df["Budget"].mean()) / movies_df["Budget"].std()
movies_df["Revenue_Normalized"] = (movies_df["Revenue"] - movies_df["Revenue"].mean()) / movies_df["Revenue"].std()

# %% [markdown]
# ### Remove Inf and -Inf Values

# %%
# Replace infinity values with NaN, then remove NaN
movies_df.replace([np.inf, -np.inf], np.nan, inplace = True)
print(len(movies_df))
# movies_df.dropna(inplace = True)
# Out:
# 7332

# %% [markdown]
# ### Clean Column Types

# %%
import ast
# for each row in the Keywords column, convert string representation of list to actual list
movies_df['Keywords'] = movies_df['Keywords'].apply(lambda x: ast.literal_eval(','.join(x)) if isinstance(x, list) else x)

# %% [markdown]
# ### Rearrange Columns

# %%
# Rearrange Columns in movies_df 
movies_df = movies_df[["IMDB_ID", "Title", "Year", "Release_Date", "Release_Month", "Age_Rating", 
                    "Overview", "Keywords", "Genre", "Directors", "Actors", "Producers", "Writers", "Composers", 
                    "Runtime", "Cinematographers", "Franchise_Name", "Production_Companies", "Country",
                    "Language", "Metascore_Rating", "IMDB_Rating", "Rotten_Tomatoes_Rating", "TMDB_Rating", "Average_Rating", 
                    "Won_Award", "Oscar_Wins", "Oscar_Nominations", "Budget", "Budget_Normalized", "Revenue", 
                    "Revenue_Normalized", "Return_On_Investment", "Popularity"]]

# %% [markdown]
# ### Drop Columns

# %%
movies_df = movies_df[movies_df["Revenue"] != 0]

print(len(movies_df))
# Out:
# 6940

# %% [markdown]
# ### Preview Cleaned Dataframe

# %%
print(f"Total Movie Count: {len(movies_df)}\n")

print(f"Clean Datatset Shape: {movies_df.shape}\n")
# Out:
# Total Movie Count: 6940
#
# Clean Datatset Shape: (6940, 34)

# %%
movies_df.info()
movies_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6940 entries, 0 to 6940
# Data columns (total 34 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   IMDB_ID                 6805 non-null   object
#  1   Title                   6940 non-null   object
#  2   Year                    6802 non-null   Int64
#  3   Release_Date            6921 non-null   datetime64[ns]
#  4   Release_Month           6921 non-null   object
#  5   Age_Rating              4541 non-null   object
#  6   Overview                6885 non-null   object
#  7   Keywords                6940 non-null   object
#  8   Genre                   6940 non-null   object
#  9   Directors               6940 non-null   object
#  10  Actors                  6940 non-null   object
#  11  Producers               6940 non-null   object
#  12  Writers                 6940 non-null   object
#  13  Composers               6940 non-null   object
#  14  Runtime                 6746 non-null   Int64
#  15  Cinematographers        6940 non-null   object
#  16  Franchise_Name          2067 non-null   object
#  17  Production_Companies    6940 non-null   object
#  18  Country                 6789 non-null   object
#  19  Language                6777 non-null   object
#  20  Metascore_Rating        4953 non-null   Float64
#  21  IMDB_Rating             6676 non-null   float64
#  22  Rotten_Tomatoes_Rating  5465 non-null   Float64
#  23  TMDB_Rating             6940 non-null   float64
#  24  Average_Rating          6940 non-null   Float64
#  25  Won_Award               6940 non-null   bool
#  26  Oscar_Wins              6940 non-null   int64
#  27  Oscar_Nominations       6940 non-null   int64
#  28  Budget                  6940 non-null   int64
#  29  Budget_Normalized       6940 non-null   float64
#  30  Revenue                 6940 non-null   int64
#  31  Revenue_Normalized      6940 non-null   float64
#  32  Return_On_Investment    5297 non-null   float64
#  33  Popularity              6940 non-null   float64
# dtypes: Float64(3), Int64(2), bool(1), datetime64[ns](1), float64(6), int64(4), object(17)
# memory usage: 1.8+ MB
#               Year                   Release_Date     Runtime  \
# count       6802.0                           6921      6746.0
# mean   2003.104822  2003-12-09 09:35:05.071521408  110.551883
# min         1914.0            1914-04-10 00:00:00         6.0
# 25%         1996.0            1996-07-19 00:00:00        95.0
# 50%         2008.0            2008-07-25 00:00:00       107.0
# 75%         2016.0            2016-11-21 00:00:00       122.0
# max         2025.0            2025-07-21 00:00:00       960.0
# std      18.278419                            NaN   26.161545
#
#        Metascore_Rating  IMDB_Rating  Rotten_Tomatoes_Rating  TMDB_Rating  \
# count            4953.0  6676.000000                  5465.0  6940.000000
# mean           5.794327     6.572034                6.211747     6.457594
# min                 0.1     1.300000                     0.0     0.000000
# 25%                 4.5     6.000000                     4.1     6.100000
# 50%                 5.8     6.600000                     6.7     6.600000
# 75%                 7.1     7.300000                     8.6     7.200000
# max                10.0     9.900000                    10.0    10.000000
# std            1.766198     1.001617                2.716969     1.357739
#
#        Average_Rating   Oscar_Wins  Oscar_Nominations        Budget  \
# count          6940.0  6940.000000        6940.000000  6.940000e+03
# mean         6.240598     0.162824           0.225072  2.977571e+07
# min               0.0     0.000000           0.000000  0.000000e+00
# 25%               5.3     0.000000           0.000000  1.372500e+04
# 50%              6.45     0.000000           0.000000  1.200000e+07
# 75%               7.4     0.000000           0.000000  4.000000e+07
# max              10.0    11.000000          11.000000  4.600000e+08
# std          1.621579     0.768677           0.811578  4.556687e+07
#
#        Budget_Normalized       Revenue  Revenue_Normalized  \
# count        6940.000000  6.940000e+03         6940.000000
# mean            0.033690  1.020252e+08            0.029609
# min            -0.625498  1.000000e+00           -0.524204
# 25%            -0.625194  8.212310e+06           -0.479626
# 50%            -0.359837  3.809388e+07           -0.317423
# 75%             0.260041  1.119062e+08            0.083246
# max             9.558198  2.923706e+09           15.346272
# std             1.008781  1.878796e+08            1.019849
#
#        Return_On_Investment   Popularity
# count          5.297000e+03  6940.000000
# mean           4.913505e+04     4.302702
# min            5.000000e-04     0.000000
# 25%            1.324981e+00     1.029475
# 50%            2.632831e+00     2.302250
# 75%            5.079769e+00     4.515750
# max            1.000042e+08   827.910300
# std            1.990570e+06    16.896609

# %%
movies_df.head()
# Out:
#       IMDB_ID                         Title  Year Release_Date Release_Month  \
# 0   tt0499549                        Avatar  2009   2009-12-15      December
# 1   tt4154796             Avengers: Endgame  2019   2019-04-24         April
# 2   tt1630029      Avatar: The Way of Water  2022   2022-12-14      December
# 3  tt34956443                      Ne Zha 2  2025   2025-01-29       January
# 4   tt2488496  Star Wars: The Force Awakens  2015   2015-12-15      December
#
#   Age_Rating                                           Overview  \
# 0      PG-13  In the 22nd century, a paraplegic Marine is di...
# 1      PG-13  After the devastating events of Avengers: Infi...
# 2      PG-13  Set more than a decade after the events of the...
# 3         NR  Following the Tribulation, although the souls ...
# 4        NaN  Thirty years after defeating the Galactic Empi...
#
#                                             Keywords  \
# 0  [paraplegic, attachment to nature, culture cla...
# 1  [superhero, time travel, space travel, time ma...
# 2  [dying and death, loss of loved one, alien lif...
# 3  [based on myths,legends or folklore, 3d animat...
# 4         [android, spacecraft, space opera, requel]
#
#                                                Genre  \
# 0  ['Action', 'Adventure', 'Fantasy', 'Science Fi...
# 1         ['Adventure', 'Science Fiction', 'Action']
# 2         ['Science Fiction', 'Adventure', 'Action']
# 3    ['Animation', 'Fantasy', 'Adventure', 'Action']
# 4         ['Adventure', 'Action', 'Science Fiction']
#
#                         Directors  \
# 0               ['James Cameron']
# 1  ['Anthony Russo', 'Joe Russo']
# 2               ['James Cameron']
# 3                     ['Yang Yu']
# 4                 ['J.J. Abrams']
#
#                                               Actors  \
# 0  ['Sam Worthington', 'Zoe Saldaña', 'Sigourney ...
# 1  ['Robert Downey Jr.', 'Chris Evans', 'Mark Ruf...
# 2  ['Sam Worthington', 'Zoe Saldaña', 'Sigourney ...
# 3  ['Lu Yanting', 'Joseph', 'Han Mo', 'Chen Hao',...
# 4  ['Harrison Ford', 'Mark Hamill', 'Carrie Fishe...
#
#                                            Producers  \
# 0                    ['James Cameron', 'Jon Landau']
# 1                                    ['Kevin Feige']
# 2                    ['Jon Landau', 'James Cameron']
# 3                                   ['Liu Wenzhang']
# 4  ['Bryan Burk', 'Kathleen Kennedy', 'J.J. Abrams']
#
#                                              Writers  \
# 0                                  ['James Cameron']
# 1          ['Stephen McFeely', 'Christopher Markus']
# 2   ['James Cameron', 'Amanda Silver', 'Rick Jaffa']
# 3                                        ['Yang Yu']
# 4  ['Michael Arndt', 'Lawrence Kasdan', 'J.J. Abr...
#
#                                  Composers  Runtime       Cinematographers  \
# 0                         ['James Horner']      162        ['Mauro Fiore']
# 1                       ['Alan Silvestri']      181      ['Trent Opaloch']
# 2                       ['Simon Franglen']      192  ['Russell Carpenter']
# 3  ['Roc Chen', 'Wan Pin Chu', 'Yang Rui']      143                     []
# 4                        ['John Williams']      138         ['Dan Mindel']
#
#             Franchise_Name                               Production_Companies  \
# 0        Avatar Collection  ['Dune Entertainment', 'Lightstorm Entertainme...
# 1  The Avengers Collection                                 ['Marvel Studios']
# 2        Avatar Collection  ['20th Century Studios', 'Lightstorm Entertain...
# 3        Ne Zha Collection  ['Chengdu Coco Cartoon', 'Beijing Enlight Pict...
# 4     Star Wars Collection                    ['Lucasfilm Ltd.', 'Bad Robot']
#
#                          Country                           Language  \
# 0  United States, United Kingdom                   English, Spanish
# 1                  United States   English, Japanese, Xhosa, German
# 2                  United States                            English
# 3                          China  Mandarin, Chinese, English, Hindi
# 4  United States, United Kingdom                            English
#
#    Metascore_Rating  IMDB_Rating  Rotten_Tomatoes_Rating  TMDB_Rating  \
# 0               8.3          7.9                     8.1          7.6
# 1               7.8          8.4                     9.4          8.2
# 2               6.7          7.5                     7.6          7.6
# 3               6.3          8.1                     9.6          8.1
# 4               8.0          7.8                     9.3          7.3
#
#    Average_Rating  Won_Award  Oscar_Wins  Oscar_Nominations     Budget  \
# 0           7.975       True           3                  0  237000000
# 1            8.45      False           0                  1  356000000
# 2            7.35       True           1                  0  460000000
# 3           8.025      False           0                  0   80000000
# 4             8.1      False           0                  5  245000000
#
#    Budget_Normalized     Revenue  Revenue_Normalized  Return_On_Investment  \
# 0           4.621319  2923706026           15.346272             12.336312
# 1           7.255797  2799439100           14.671726              7.863593
# 2           9.558198  2320250281           12.070591              5.044022
# 3           1.145579  2213230000           11.489663             27.665375
# 4           4.798427  2068223624           10.702538              8.441729
#
#    Popularity
# 0     22.0122
# 1     16.8250
# 2     23.3720
# 3     35.9241
# 4      9.8780

# %% [markdown]
# ### Save Processed Dataframe

# %%
movies_df.to_csv("../data/processed/cleaned_movies.csv", index = False)

# %% [markdown]
# ## Prepare Data for Regression
#
# We will drop columns related to the outcome variable and those that wouldn't exist before the release of a movie. Our target variables will be `Revenue_Normalized` and `Average_Rating`.
#
# We also want to deal with the columns that contains lists of strings, such as `Genre`, `Directors`, `Actors`, etc. These lists are a little tricky to handle, so we will transform them into counts of features. For example, we will count the number of unique genres, directors, actors, etc., and create new columns for these counts. We drop the original columns after creating the new ones and also the `num_actors` since it is redundant with all movies showing the 10 top actors, which was specified in the data colletion process.

# %%
import pandas as pd
import ast

# Load the data
df = pd.read_csv("../data/processed/cleaned_movies.csv")

# Drop unwanted columns
cols_to_drop = [
    "IMDB_ID", "Title", "Overview", "Keywords", "Metascore_Rating", "IMDB_Rating",
    "Rotten_Tomatoes_Rating", "TMDB_Rating", "Won_Award", "Oscar_Wins",
    "Oscar_Nominations","Revenue", "Return_On_Investment", "Popularity",
    # "Average_Rating", "Revenue_Normalized"
]

df_clean = df.drop(columns=cols_to_drop)

# Remove rows with missing essential features (e.g., budget)
df_clean = df_clean[df_clean["Budget"].notna()]

# Fill or drop NA for other columns (basic handling)
df_clean = df_clean.dropna(subset=["Runtime", "Age_Rating", "Genre", "Language", "Country"])

# Encode release month as numeric
df_clean["Release_Month"] = pd.Categorical(df_clean["Release_Month"])
df_clean["Release_Month"] = df_clean["Release_Month"].cat.codes

# define columns that contain lists of strings
list_cols = ['Genre', 'Directors', 'Actors', 'Producers', 'Writers',
             'Composers', 'Cinematographers', 'Production_Companies']

for col in list_cols:
    # convert string representation of list to actual list
    df_clean[col] = df_clean[col].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else [])
    # count features 
    df_clean[f'num_{col.lower()}'] = df_clean[col].apply(len)

# drop those columns that have lists, also drop num_actors
df_clean = df_clean.drop(columns=list_cols + ["num_actors"])

# Save cleaned version
df_clean.to_csv("../data/processed/cleaned_movies_reg.csv", index=False)
