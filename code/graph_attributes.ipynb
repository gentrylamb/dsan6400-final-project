# %% [markdown]
# ---
# title: "Graph Attributes"
# ---

# %% [markdown]
# ### Imports

# %%
import networkx as nx

# %% [markdown]
# ### Network Summary

# %%
# Load GML graph
G = nx.read_graphml("../data/networks/crew_collaboration_network.graphml")

# Inspect basic stats
def network_summary(G):

    def centrality_stats(x):
        x1=dict(x)
        x2=np.array(list(x1.values())); #print(x2)
        print("	min:" ,min(x2))
        print("	mean:" ,np.mean(x2))
        print("	median:" ,np.median(x2))
        # print("	mode:" ,stats.mode(x2)[0][0])
        print("	max:" ,max(x2))
        x=dict(x)
        sort_dict=dict(sorted(x1.items(), key=lambda item: item[1],reverse=True))
        print("	top nodes:",list(sort_dict)[0:6])
        print("	          ",list(sort_dict.values())[0:6])

    try: 
        print("GENERAL")
        print("	number of nodes:",len(list(G.nodes)))
        print("	number of edges:",len(list(G.edges)))

        print("	is_directed:", nx.is_directed(G))
        print("	is_weighted:" ,nx.is_weighted(G))


        if(nx.is_directed(G)):
            print("IN-DEGREE (NORMALIZED)")
            centrality_stats(nx.in_degree_centrality(G))
            print("OUT-DEGREE (NORMALIZED)")
            centrality_stats(nx.out_degree_centrality(G))
        else:
            print("	number_connected_components: ", nx.number_connected_components(G))
            print("	number of triangle: ",len(nx.triangles(G).keys()))
            print("	density:" ,nx.density(G))
            print("	average_clustering coefficient: ", nx.average_clustering(G))
            print("	degree_assortativity_coefficient: ", nx.degree_assortativity_coefficient(G))
            print("	is_tree:" ,nx.is_tree(G))

            if(nx.is_connected(G)):
                print("	diameter:" ,nx.diameter(G))
                print("	radius:" ,nx.radius(G))
                print("	average_shortest_path_length: ", nx.average_shortest_path_length(G))

            #CENTRALITY 
            print("DEGREE (NORMALIZED)")
            centrality_stats(nx.degree_centrality(G))

            print("CLOSENESS CENTRALITY")
            centrality_stats(nx.closeness_centrality(G))

            print("BETWEEN CENTRALITY")
            centrality_stats(nx.betweenness_centrality(G))
    except:
        print("unable to run")

network_summary(G)
# Out:
# GENERAL
# 	number of nodes: 488
# 	number of edges: 2737
# 	is_directed: False
# 	is_weighted: True
# 	number_connected_components:  15
# 	number of triangle:  488
# 	density: 0.023033291816743528
# 	average_clustering coefficient:  0.9452172888448204
# 	degree_assortativity_coefficient:  0.03982778978752595
# 	is_tree: False
# DEGREE (NORMALIZED)
# unable to run

# %% [markdown]
# ### Compute Network Attributes

# %%
# compute centraility measures

print("DEGREE (NORMALIZED)")
print(nx.degree_centrality(G))

print("CLOSENESS CENTRALITY")
print(nx.closeness_centrality(G))

print("BETWEEN CENTRALITY")
print(nx.betweenness_centrality(G))
# Out:
# DEGREE (NORMALIZED)
# {'Craig T. Nelson': 0.018480492813141684, 'Holly Hunter': 0.018480492813141684, 'Sarah Vowell': 0.018480492813141684, 'Spencer Fox': 0.018480492813141684, 'Jason Lee': 0.018480492813141684, 'Samuel L. Jackson': 0.059548254620123205, 'Elizabeth Peña': 0.018480492813141684, 'Eli Fucile': 0.018480492813141684, 'Maeve Andrews': 0.018480492813141684, 'Brad Bird': 0.022587268993839837, 'Will Smith': 0.04106776180698152, 'Charlize Theron': 0.02053388090349076, 'Jason Bateman': 0.02053388090349076, 'Jae Head': 0.02053388090349076, 'Eddie Marsan': 0.04106776180698152, 'David Mattey': 0.02053388090349076, 'Maetrix Fitten': 0.02053388090349076, 'Thomas Lennon': 0.02053388090349076, 'Johnny Galecki': 0.02053388090349076, 'Hayley Marie Norman': 0.02053388090349076, 'Peter Berg': 0.02053388090349076, 'Wu Jing': 0.024640657084188913, 'Jackson Yee': 0.024640657084188913, 'Duan Yihong': 0.024640657084188913, 'Zhu Yawen': 0.024640657084188913, 'Jerry Lee': 0.024640657084188913, 'Elvis Han': 0.024640657084188913, 'Zhang Hanyu': 0.043121149897330596, 'Geng Le': 0.024640657084188913, 'Du Chun': 0.024640657084188913, 'Yang Yiwei': 0.024640657084188913, 'Tsui Hark': 0.024640657084188913, 'Chen Kaige': 0.024640657084188913, 'Dante Lam Chiu-Yin': 0.043121149897330596, 'Vin Diesel': 0.02053388090349076, 'Paul Walker': 0.02053388090349076, 'Jordana Brewster': 0.02053388090349076, 'Tyrese Gibson': 0.02053388090349076, 'Ludacris': 0.02053388090349076, 'Matt Schulze': 0.02053388090349076, 'Sung Kang': 0.02053388090349076, 'Gal Gadot': 0.02053388090349076, 'Tego Calderon': 0.02053388090349076, 'Don Omar': 0.02053388090349076, 'Justin Lin': 0.02053388090349076, 'Robert Downey Jr.': 0.055441478439425054, 'Gwyneth Paltrow': 0.034907597535934295, 'Don Cheadle': 0.02053388090349076, 'Scarlett Johansson': 0.02053388090349076, 'Sam Rockwell': 0.02053388090349076, 'Mickey Rourke': 0.02053388090349076, 'Clark Gregg': 0.034907597535934295, 'John Slattery': 0.02053388090349076, 'Garry Shandling': 0.02053388090349076, 'Jon Favreau': 0.034907597535934295, 'Paul Rudd': 0.03080082135523614, 'Evangeline Lilly': 0.03080082135523614, 'Michael Douglas': 0.03080082135523614, 'Hannah John-Kamen': 0.04106776180698152, 'Randall Park': 0.02053388090349076, 'Michelle Pfeiffer': 0.04106776180698152, 'Laurence Fishburne': 0.02053388090349076, 'Michael Peña': 0.03080082135523614, 'Walton Goggins': 0.02053388090349076, 'Bobby Cannavale': 0.03080082135523614, 'Peyton Reed': 0.03080082135523614, 'Jay Baruchel': 0.02053388090349076, 'Cate Blanchett': 0.02053388090349076, 'Gerard Butler': 0.039014373716632446, 'Craig Ferguson': 0.043121149897330596, 'America Ferrera': 0.02053388090349076, 'Jonah Hill': 0.02053388090349076, 'Christopher Mintz-Plasse': 0.02053388090349076, 'T.J. Miller': 0.04106776180698152, 'Kristen Wiig': 0.02053388090349076, 'Djimon Hounsou': 0.02053388090349076, 'Dean DeBlois': 0.039014373716632446, 'Hugh Jackman': 0.02053388090349076, 'Dafne Keen': 0.02053388090349076, 'Patrick Stewart': 0.02053388090349076, 'Elizabeth Rodriguez': 0.02053388090349076, 'Boyd Holbrook': 0.02053388090349076, 'Stephen Merchant': 0.02053388090349076, 'Richard E. Grant': 0.02053388090349076, 'Stephen Dunlevy': 0.02053388090349076, 'Eriq La Salle': 0.02053388090349076, 'Elise Neal': 0.02053388090349076, 'James Mangold': 0.02053388090349076, 'Jeff Goldblum': 0.02053388090349076, 'Julianne Moore': 0.02053388090349076, 'Pete Postlethwaite': 0.04106776180698152, 'Arliss Howard': 0.02053388090349076, 'Richard Attenborough': 0.02053388090349076, 'Vince Vaughn': 0.04106776180698152, 'Vanessa Lee Chester': 0.02053388090349076, 'Peter Stormare': 0.04106776180698152, 'Harvey Jason': 0.02053388090349076, 'Richard Schiff': 0.02053388090349076, 'Steven Spielberg': 0.04106776180698152, 'Tye Sheridan': 0.04106776180698152, 'Olivia Cooke': 0.02053388090349076, 'Ben Mendelsohn': 0.02053388090349076, 'Lena Waithe': 0.02053388090349076, 'Simon Pegg': 0.04722792607802875, 'Mark Rylance': 0.04106776180698152, 'Phi ...
# CLOSENESS CENTRALITY
# {'Craig T. Nelson': 0.12598378696929022, 'Holly Hunter': 0.12598378696929022, 'Sarah Vowell': 0.12598378696929022, 'Spencer Fox': 0.12598378696929022, 'Jason Lee': 0.12598378696929022, 'Samuel L. Jackson': 0.1548357440734502, 'Elizabeth Peña': 0.12598378696929022, 'Eli Fucile': 0.12598378696929022, 'Maeve Andrews': 0.12598378696929022, 'Brad Bird': 0.12598378696929022, 'Will Smith': 0.1360070766182053, 'Charlize Theron': 0.11759895998419764, 'Jason Bateman': 0.11759895998419764, 'Jae Head': 0.11759895998419764, 'Eddie Marsan': 0.12907731151120036, 'David Mattey': 0.11759895998419764, 'Maetrix Fitten': 0.11759895998419764, 'Thomas Lennon': 0.11759895998419764, 'Johnny Galecki': 0.11759895998419764, 'Hayley Marie Norman': 0.11759895998419764, 'Peter Berg': 0.11759895998419764, 'Wu Jing': 0.030184804928131415, 'Jackson Yee': 0.030184804928131415, 'Duan Yihong': 0.030184804928131415, 'Zhu Yawen': 0.030184804928131415, 'Jerry Lee': 0.030184804928131415, 'Elvis Han': 0.030184804928131415, 'Zhang Hanyu': 0.043121149897330596, 'Geng Le': 0.030184804928131415, 'Du Chun': 0.030184804928131415, 'Yang Yiwei': 0.030184804928131415, 'Tsui Hark': 0.030184804928131415, 'Chen Kaige': 0.030184804928131415, 'Dante Lam Chiu-Yin': 0.043121149897330596, 'Vin Diesel': 0.02053388090349076, 'Paul Walker': 0.02053388090349076, 'Jordana Brewster': 0.02053388090349076, 'Tyrese Gibson': 0.02053388090349076, 'Ludacris': 0.02053388090349076, 'Matt Schulze': 0.02053388090349076, 'Sung Kang': 0.02053388090349076, 'Gal Gadot': 0.02053388090349076, 'Tego Calderon': 0.02053388090349076, 'Don Omar': 0.02053388090349076, 'Justin Lin': 0.02053388090349076, 'Robert Downey Jr.': 0.13671452565132988, 'Gwyneth Paltrow': 0.13027691477803308, 'Don Cheadle': 0.12971433710780098, 'Scarlett Johansson': 0.12971433710780098, 'Sam Rockwell': 0.12971433710780098, 'Mickey Rourke': 0.12971433710780098, 'Clark Gregg': 0.13027691477803308, 'John Slattery': 0.12971433710780098, 'Garry Shandling': 0.12971433710780098, 'Jon Favreau': 0.13027691477803308, 'Paul Rudd': 0.16621892525829673, 'Evangeline Lilly': 0.16621892525829673, 'Michael Douglas': 0.16621892525829673, 'Hannah John-Kamen': 0.20374703532145869, 'Randall Park': 0.16556452004074437, 'Michelle Pfeiffer': 0.17910301571698922, 'Laurence Fishburne': 0.16556452004074437, 'Michael Peña': 0.16621892525829673, 'Walton Goggins': 0.16556452004074437, 'Bobby Cannavale': 0.16621892525829673, 'Peyton Reed': 0.16621892525829673, 'Jay Baruchel': 0.15633229773363969, 'Cate Blanchett': 0.15633229773363969, 'Gerard Butler': 0.1573854344698693, 'Craig Ferguson': 0.15762139464148828, 'America Ferrera': 0.15633229773363969, 'Jonah Hill': 0.15633229773363969, 'Christopher Mintz-Plasse': 0.15633229773363969, 'T.J. Miller': 0.19930515682629896, 'Kristen Wiig': 0.15633229773363969, 'Djimon Hounsou': 0.15633229773363969, 'Dean DeBlois': 0.1573854344698693, 'Hugh Jackman': 0.02053388090349076, 'Dafne Keen': 0.02053388090349076, 'Patrick Stewart': 0.02053388090349076, 'Elizabeth Rodriguez': 0.02053388090349076, 'Boyd Holbrook': 0.02053388090349076, 'Stephen Merchant': 0.02053388090349076, 'Richard E. Grant': 0.02053388090349076, 'Stephen Dunlevy': 0.02053388090349076, 'Eriq La Salle': 0.02053388090349076, 'Elise Neal': 0.02053388090349076, 'James Mangold': 0.02053388090349076, 'Jeff Goldblum': 0.19202460315227887, 'Julianne Moore': 0.19202460315227887, 'Pete Postlethwaite': 0.1965111593006966, 'Arliss Howard': 0.19202460315227887, 'Richard Attenborough': 0.19202460315227887, 'Vince Vaughn': 0.20839141769251274, 'Vanessa Lee Chester': 0.19202460315227887, 'Peter Stormare': 0.20634635961898468, 'Harvey Jason': 0.19202460315227887, 'Richard Schiff': 0.19202460315227887, 'Steven Spielberg': 0.2227404030209167, 'Tye Sheridan': 0.19930515682629896, 'Olivia Cooke': 0.19379441516289897, 'Ben Mendelsohn': 0.19379441516289897, 'Lena Waithe': 0.19379441516289897, 'Simon Pegg': 0.20859815521006483, 'Mark Rylance': 0.20063639356082574, 'Philip Zhao': 0.1937944151 ...
# BETWEEN CENTRALITY
# {'Craig T. Nelson': 0.0, 'Holly Hunter': 0.0, 'Sarah Vowell': 0.0, 'Spencer Fox': 0.0, 'Jason Lee': 0.0, 'Samuel L. Jackson': 0.07912269478481185, 'Elizabeth Peña': 0.0, 'Eli Fucile': 0.0, 'Maeve Andrews': 0.0, 'Brad Bird': 0.0, 'Will Smith': 0.033327202827455625, 'Charlize Theron': 0.0, 'Jason Bateman': 0.0, 'Jae Head': 0.0, 'Eddie Marsan': 0.02637525886889519, 'David Mattey': 0.0, 'Maetrix Fitten': 0.0, 'Thomas Lennon': 0.0, 'Johnny Galecki': 0.0, 'Hayley Marie Norman': 0.0, 'Peter Berg': 0.0, 'Wu Jing': 0.0, 'Jackson Yee': 0.0, 'Duan Yihong': 0.0, 'Zhu Yawen': 0.0, 'Jerry Lee': 0.0, 'Elvis Han': 0.0, 'Zhang Hanyu': 0.00041828275914518217, 'Geng Le': 0.0, 'Du Chun': 0.0, 'Yang Yiwei': 0.0, 'Tsui Hark': 0.0, 'Chen Kaige': 0.0, 'Dante Lam Chiu-Yin': 0.00041828275914518217, 'Vin Diesel': 0.0, 'Paul Walker': 0.0, 'Jordana Brewster': 0.0, 'Tyrese Gibson': 0.0, 'Ludacris': 0.0, 'Matt Schulze': 0.0, 'Sung Kang': 0.0, 'Gal Gadot': 0.0, 'Tego Calderon': 0.0, 'Don Omar': 0.0, 'Justin Lin': 0.0, 'Robert Downey Jr.': 0.038153352450570326, 'Gwyneth Paltrow': 0.003446239025773142, 'Don Cheadle': 0.0, 'Scarlett Johansson': 0.0, 'Sam Rockwell': 0.0, 'Mickey Rourke': 0.0, 'Clark Gregg': 0.003446239025773142, 'John Slattery': 0.0, 'Garry Shandling': 0.0, 'Jon Favreau': 0.003446239025773142, 'Paul Rudd': 0.002182957160521994, 'Evangeline Lilly': 0.002182957160521994, 'Michael Douglas': 0.002182957160521994, 'Hannah John-Kamen': 0.043228014093501556, 'Randall Park': 0.0, 'Michelle Pfeiffer': 0.025748180794974786, 'Laurence Fishburne': 0.0, 'Michael Peña': 0.002182957160521994, 'Walton Goggins': 0.0, 'Bobby Cannavale': 0.002182957160521994, 'Peyton Reed': 0.002182957160521994, 'Jay Baruchel': 0.0, 'Cate Blanchett': 0.0, 'Gerard Butler': 0.01178796866681877, 'Craig Ferguson': 0.02872208279463584, 'America Ferrera': 0.0, 'Jonah Hill': 0.0, 'Christopher Mintz-Plasse': 0.0, 'T.J. Miller': 0.07351636372854717, 'Kristen Wiig': 0.0, 'Djimon Hounsou': 0.0, 'Dean DeBlois': 0.01178796866681877, 'Hugh Jackman': 0.0, 'Dafne Keen': 0.0, 'Patrick Stewart': 0.0, 'Elizabeth Rodriguez': 0.0, 'Boyd Holbrook': 0.0, 'Stephen Merchant': 0.0, 'Richard E. Grant': 0.0, 'Stephen Dunlevy': 0.0, 'Eriq La Salle': 0.0, 'Elise Neal': 0.0, 'James Mangold': 0.0, 'Jeff Goldblum': 0.0, 'Julianne Moore': 0.0, 'Pete Postlethwaite': 0.044392792596578204, 'Arliss Howard': 0.0, 'Richard Attenborough': 0.0, 'Vince Vaughn': 0.04319477451596334, 'Vanessa Lee Chester': 0.0, 'Peter Stormare': 0.08441498271013023, 'Harvey Jason': 0.0, 'Richard Schiff': 0.0, 'Steven Spielberg': 0.09692364869009186, 'Tye Sheridan': 0.02422075471166656, 'Olivia Cooke': 0.0, 'Ben Mendelsohn': 0.0, 'Lena Waithe': 0.0, 'Simon Pegg': 0.09249956078515326, 'Mark Rylance': 0.045178557299250924, 'Philip Zhao': 0.0, 'Win Morisaki': 0.0, 'Mark Wahlberg': 0.0, 'Laura Haddock': 0.0, 'Peter Cullen': 0.0, 'Anthony Hopkins': 0.0, 'Erik Aadahl': 0.0, 'Josh Duhamel': 0.0, 'Gemma Chan': 0.0, 'Jim Carter': 0.0, 'Santiago Cabrera': 0.0, 'Isabela Merced': 0.0, 'Michael Bay': 0.02619548592626393, 'Daniel Craig': 0.0008004891024145382, 'Eva Green': 0.0, 'Mads Mikkelsen': 0.01294261693391508, 'Judi Dench': 0.0008004891024145382, 'Jeffrey Wright': 0.0008004891024145382, 'Giancarlo Giannini': 0.0008004891024145382, 'Caterina Murino': 0.0, 'Simon Abkarian': 0.0, 'Isaach de Bankolé': 0.0, 'Jesper Christensen': 0.0008004891024145382, 'Martin Campbell': 0.0, 'Olga Kurylenko': 0.0, 'Mathieu Amalric': 0.0, 'Gemma Arterton': 0.010673470115886518, 'David Harbour': 0.0, 'Anatole Taubman': 0.0, 'Marc Forster': 0.015870204448683443, 'Tommy Lee Jones': 0.0, 'Linda Fiorentino': 0.0, "Vincent D'Onofrio": 0.0, 'Rip Torn': 0.0, 'Tony Shalhoub': 0.048715501613731435, 'Siobhan Fallon Hogan': 0.0, 'Mike Nussbaum': 0.0, 'Jon Gries': 0.0, 'Sergio Calderón': 0.0, 'Barry Sonnenfeld': 0.0, 'Nicolas Cage': 0.0, 'Emma Stone': 0.0, 'Ryan Reynolds': 0.0, 'Catherine Keener': 0.0, 'Cloris Leachman': 0.0, 'Clark Duke': 0.0, 'Chris Sanders': 0.0, 'Randy Thom': 0.0,  ...
